# %% [markdown]
# <a href="https://colab.research.google.com/github/simransirsat/MLPracticals/blob/main/MLE8B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Exp 8B - ANN using PyTorch

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
X = torch.FloatTensor([5, 2, 1])
y = torch.FloatTensor([0.1, 0.05])

# %%
lr = 0.01

# %%
class NN(nn.Module):

    def __init__(self, input_size, output_size):
        super().__init__()
        self.hidden1 = nn.Linear(input_size, 10)
        self.out = nn.Linear(10, output_size)

    def forward(self, X):
        out = self.hidden1(X)
        out = torch.sigmoid(out)
        out = self.out(out)
        out = torch.sigmoid(out)
        return out

# %%
torch.manual_seed(42)
model = NN(3, 2)

epochs = 1000
criterion = nn.MSELoss()
optimizer = torch.optim.SGD(model.parameters(), lr=lr)

losses = []
for i in range(epochs):
    optimizer.zero_grad()

    out = model(X)
    loss = criterion(out, y)
    losses.append(loss.item())
    print(f'Epoch {i + 1} / {epochs}: Loss = {loss.item()}')

    loss.backward()
    optimizer.step()
# Out:
# Epoch 1 / 1000: Loss = 0.16778360307216644
# Epoch 2 / 1000: Loss = 0.16679750382900238
# Epoch 3 / 1000: Loss = 0.16581681370735168
# Epoch 4 / 1000: Loss = 0.16484157741069794
# Epoch 5 / 1000: Loss = 0.16387179493904114
# Epoch 6 / 1000: Loss = 0.1629074215888977
# Epoch 7 / 1000: Loss = 0.16194842755794525
# Epoch 8 / 1000: Loss = 0.16099485754966736
# Epoch 9 / 1000: Loss = 0.16004669666290283
# Epoch 10 / 1000: Loss = 0.1591038852930069
# Epoch 11 / 1000: Loss = 0.15816645324230194
# Epoch 12 / 1000: Loss = 0.15723440051078796
# Epoch 13 / 1000: Loss = 0.1563076674938202
# Epoch 14 / 1000: Loss = 0.1553862988948822
# Epoch 15 / 1000: Loss = 0.1544702649116516
# Epoch 16 / 1000: Loss = 0.15355953574180603
# Epoch 17 / 1000: Loss = 0.15265409648418427
# Epoch 18 / 1000: Loss = 0.1517539620399475
# Epoch 19 / 1000: Loss = 0.15085910260677338
# Epoch 20 / 1000: Loss = 0.14996950328350067
# Epoch 21 / 1000: Loss = 0.1490851789712906
# Epoch 22 / 1000: Loss = 0.14820605516433716
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(range(epochs), losses)
